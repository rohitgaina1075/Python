# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
d1 = {"key": "rohit"}

# %%
d1
# Out:
# {'key': 'rohit'}

# %%
d2 = {'name':"Rohit", "email":"rohit232@gmail.com","number": 343455}

# %%
d2
# Out:
# {'name': 'Rohit', 'email': 'rohit232@gmail.com', 'number': 343455}

# %%
d3 = {34:"rohti", '@dfkjhdf': "kumar" , True: 3425}

# %%
d3
# Out:
# {34325: 'rohti', '@dfkjhdf': 'kumar', True: 3425}

# %%
d3[34]
# Out:
# 'rohti'

# %%
d3[True]
# Out:
# 3425

# %%
d3[1]
# Out:
# 3425

# %%
d4 = {'name':"rohit",'email':"rolhtijs34@gmail.com", 'name':"rahul"}

# %%
d4['name']
# Out:
# 'rahul'

# %%
d5 ={'company':"ducat", 'course' :["webb dev", "data science", "java"]}

# %%
d5['course']
# Out:
# ['webb dev', 'data science', 'java']

# %%
d5
# Out:
# {'company': 'ducat', 'course': ['webb dev', 'data science', 'java']}

# %%
d5['course'][1]
# Out:
# 'data science'

# %%
d6 = {"number":[2,34,44,563,34,52, 34], "assignment":(1,2,3,4,5,6),"Launch_date":{28,12,14},"class_time":{"webb dev":8, "data science":3, "java":9}}

# %%
d6
# Out:
# {'number': [2, 34, 44, 563, 34, 52, 34],
#  'assignment': (1, 2, 3, 4, 5, 6),
#  'Launch_date': {12, 14, 28},
#  'class_time': {'webb dev': 8, 'data science': 3, 'java': 9}}

# %%
d6['class_time']['java']
# Out:
# 9

# %%
d6["mentor"]=["aman","rahul","krish"]

# %%
d6
# Out:
# {'number': [2, 34, 44, 563, 34, 52, 34],
#  'assignment': (1, 2, 3, 4, 5, 6),
#  'Launch_date': {12, 14, 28},
#  'class_time': {'webb dev': 8, 'data science': 3, 'java': 9},
#  'mentor': ['aman', 'rahul', 'krish']}

# %%
d6['Launch_date']= [12, 14, 28,45,45]

# %%
d6
# Out:
# {'number': [2, 34, 44, 563, 34, 52, 34],
#  'assignment': (1, 2, 3, 4, 5, 6),
#  'Launch_date': [12, 14, 28, 45, 45],
#  'class_time': {'webb dev': 8, 'data science': 3, 'java': 9},
#  'mentor': ['aman', 'rahul', 'krish']}

# %%
list(d6.keys())
# Out:
# ['number', 'assignment', 'Launch_date', 'class_time', 'mentor']

# %%
list(d6.values())
# Out:
# [[2, 34, 44, 563, 34, 52, 34],
#  (1, 2, 3, 4, 5, 6),
#  [12, 14, 28, 45, 45],
#  {'webb dev': 8, 'data science': 3, 'java': 9},
#  ['aman', 'rahul', 'krish']]

# %%
list(d6.items())
# Out:
# [('number', [2, 34, 44, 563, 34, 52, 34]),
#  ('assignment', (1, 2, 3, 4, 5, 6)),
#  ('Launch_date', [12, 14, 28, 45, 45]),
#  ('class_time', {'webb dev': 8, 'data science': 3, 'java': 9}),
#  ('mentor', ['aman', 'rahul', 'krish'])]

# %%
d6.keys()
# Out:
# dict_keys(['number', 'assignment', 'Launch_date', 'class_time', 'mentor'])

# %%
d6
# Out:
# {'number': [2, 34, 44, 563, 34, 52, 34],
#  'Launch_date': [12, 14, 28, 45, 45],
#  'class_time': {'webb dev': 8, 'data science': 3, 'java': 9},
#  'mentor': ['aman', 'rahul', 'krish']}

# %%
marks = int(input("Enter your marks"))
if marks >= 80:
    print("You will be a part A0 batch")
elif marks >= 60 and marks <= 80:
    print("You will be a part A1 batch")
elif marks >=40 and marks <=60:
    print("You will be a part A2 batch")
else:
    print("You will be a part A3 batch")
# Out:
# Enter your marks 45
# You will be a part A2 batch

# %%
marks
# Out:
# 45

# %%
if sales >=100 :
    print("You get a 20% discount")
elif sales >=80 and sales <=80:
    print("You get a 10% discount")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 if sales >=100 :
#       2     print("You get a 20% discount")
#       3 elif sales >=80 and sales <=80:
#
# NameError: name 'sales' is not defined

# %%
price = int(input("Enter your price"))
if price > 1000:
    print("I will not purchase")
else :
    print("I will purchase")
# Out:
# Enter your price 1100
# I will not purchase

# %%
price = int(input("Enter your price"))
if price > 1000:
    print("I will not purchase")
    if price >5000:
        print("this is too much")
    elif price < 2000:
        print("It's okk")
# Out:
# Enter your price 1500
# I will not purchase
# It's okk

# %%
l = [1,2,3,4,5,6,7,8,10,11]

# %%
l[+1]
# Out:
# 2

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 10, 11]

# %%
l[0]+1
# Out:
# 2

# %%
l1 = []

# %%
l.append(l[0]+1)

# %%
l
# Out:
# [1, 2]

# %%
l
# Out:
# [1, 2]

# %%
l = [1,2,3,4,5,6,7,8,10,11]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 10, 11]

# %%
l1 =[]
for i in l:
    print(i+1)
    l1.append(i+1)
l1
# Out:
# 2
# 3
# 4
# 5
# 6
# 7
# 8
# 9
# 11
# 12
# [2, 3, 4, 5, 6, 7, 8, 9, 11, 12]

# %%
l = ["rohit","kumar","rahul ","fdshs"]

# %%
l1 = []
for i in l :
    print(i)
    l1.append(i.upper())
# Out:
# rohit
# kumar
# rahul
# fdshs

# %%
l1
# Out:
# []

# %%
l1
# Out:
# ['ROHIT', 'KUMAR', 'RAHUL ', 'FDSHS']

# %%
l = [1,23 ,343,343,"rohit",2,234,556,"ans"]

# %%
l1_num =[]
l2_str =[]
for i in l :
    if type(i) == int or type(i) == float:
        l1_num.append(i)
    else :
        l2_str.append(i)

# %%
l1_num
# Out:
# [1, 23, 343, 343, 2, 234, 556]

# %%
l2_str
# Out:
# ['rohit', 'ans']
