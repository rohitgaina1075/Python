# %%
print("Hello word")
# Out:
# Hello word

# %%
print("I am learn data science in ducat")
# Out:
# I am learn data science in ducat

# %%
name = ("Rohit")
age = 34
city =("sirsa")

# %%
print(name)
# Out:
# Rohit

# %%
print(age)
# Out:
# 34

# %%
print(city)
# Out:
# sirsa

# %%
s = "ducatsikills"

# %%
s[2]
# Out:
# 'c'

# %%
s[-8]
# Out:
# 't'

# %%
s[0:3]
# Out:
# 'duc'

# %%
s[0:7:2]
# Out:
# 'dcti'

# %%
s[0:8:2]
# Out:
# 'dcti'

# %%
s[0::2]
# Out:
# 'dctiil'

# %%
s[2::2]
# Out:
# 'ctiil'

# %%
s[::-1]
# Out:
# 'sllikistacud'

# %%
s[2:7:-1]
# Out:
# ''

# %%
s[8:0]
# Out:
# ''

# %%
s[8:0:-1]
# Out:
# 'ikistacu'

# %%
s[-2:-8:-1]
# Out:
# 'llikis'

# %%
s[-2::-1]
# Out:
# 'llikistacud'

# %%
s[::-1]
# Out:
# 'sllikistacud'

# %%
s[::1]
# Out:
# 'ducatsikills'

# %%
s[90]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 s[90]
#
# IndexError: string index out of range

# %%
s[-90]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 s[-90]
#
# IndexError: string index out of range

# %%
s[:-90:-1]
# Out:
# 'sllikistacud'

# %%
True +True
# Out:
# 2

# %%
type(True)
# Out:
# bool

# %%
i = 4 +8j

# %%
type(i)
# Out:
# complex

# %%
i.real
# Out:
# 4.0

# %%
i.imag
# Out:
# 8.0

# %%
i =[8 , 123,"djfj",True, 5 +4j , 234.34]

# %%
type(i)
# Out:
# list

# %%
i[0]
# Out:
# 8

# %%
i[4]
# Out:
# (5+4j)

# %%
i[90]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 i[90]
#
# IndexError: list index out of range

# %%
i[-90]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 i[-90]
#
# IndexError: list index out of range

# %%
i
# Out:
# [8, 123, 'djfj', True, (5+4j), 234.34]

# %%
i[0:4]
# Out:
# [8, 123, 'djfj', True]

# %%
i[0:1:2]
# Out:
# [8]

# %%
i[0:-1]
# Out:
# [8, 123, 'djfj', True, (5+4j)]

# %%
i[::-1]
# Out:
# [234.34, (5+4j), True, 'djfj', 123, 8]

# %%
i[::2]
# Out:
# [8, 'djfj', (5+4j)]

# %%
s = "ducatskills"

# %%
i +s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 i +s
#
# TypeError: can only concatenate list (not "str") to list

# %%
list(s)
# Out:
# ['d', 'u', 'c', 'a', 't', 's', 'k', 'i', 'l', 'l', 's']

# %%
list(s)+i
# Out:
# ['d',
#  'u',
#  'c',
#  'a',
#  't',
#  's',
#  'k',
#  'i',
#  'l',
#  'l',
#  's',
#  8,
#  123,
#  'djfj',
#  True,
#  (5+4j),
#  234.34]

# %%
i
# Out:
# [8, 123, 'djfj', True, (5+4j), 234.34]

# %%
i[3]
# Out:
# True

# %%
type(i[2])
# Out:
# str

# %%
i[2][0:2]
# Out:
# 'dj'
