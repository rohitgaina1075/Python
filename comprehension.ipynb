# %%
# comprehension (ek line me code likna )

# %%
l = [1,2,3,4,5]
l1 = []
for i in l:
    l1.append(i**2)

# %%
l1
# Out:
# [1, 4, 9, 16, 25]

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
[i**2 for i in l]
# Out:
# [1, 4, 9, 16, 25]

# %%
[i for i in l if i % 2 == 0]
# Out:
# [2, 4]

# %%
l1 =["Rohit","aman","ducat","data science master"]

# %%
l1
# Out:
# ['Rohit', 'aman', 'ducat', 'data science master']

# %%
[i.upper() for i in l1]
# Out:
# ['ROHIT', 'AMAN', 'DUCAT', 'DATA SCIENCE MASTER']

# %% [markdown]
# l

# %%
l
# Out:
# [1, 2, 3, 4, 5]

# %%
list(i**2 for i in l)
# Out:
# [1, 4, 9, 16, 25]

# %%
d = {"key1":1,"kay2":2,"key3":3,"key4":4}

# %%
{k:v**2 for k , v in d.items()}
# Out:
# {'key1': 1, 'kay2': 4, 'key3': 9, 'key4': 16}

# %%
d.items()
# Out:
# dict_items([('key1', 1), ('kay2', 2), ('key3', 3), ('key4', 4)])

# %%
d = {"key1":1,"kay2":2,"key3":3,"key4":4}

# %%
{k:v for k , v in d.items() if v >1}
# Out:
# {'kay2': 2, 'key3': 3, 'key4': 4}
